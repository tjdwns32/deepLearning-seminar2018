# %%
# Keras import
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization
from keras.wrappers.scikit_learn import KerasClassifier

# Sklearn import
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

import time
# Out:
# C:\Users\tjdwn\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
num_classes = 10

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(
            loss=keras.losses.categorical_crossentropy,
            optimizer='adam',
            metrics=['accuracy']
)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.time()
model.fit(
    X_train, 
    y_train,
    epochs=10,
    batch_size=100,
    verbose=1
)
print("End Time: ", time.time() - start_time)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.3614 - acc: 0.8976
# Epoch 2/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.1527 - acc: 0.9552
# Epoch 3/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.1106 - acc: 0.9678
# Epoch 4/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.0890 - acc: 0.9728
# Epoch 5/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.0738 - acc: 0.9774
# Epoch 6/10
# 60000/60000 [==============================] - 1s 15us/step - loss: 0.0609 - acc: 0.9812
# Epoch 7/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.0526 - acc: 0.9837
# Epoch 8/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.0455 - acc: 0.9857
# Epoch 9/10
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.0383 - acc: 0.9881
# Epoch 10/10
# 60000/60000 [==============================] - 1s 15us/step - loss: 0.0333 - acc: 0.9897
# End Time:  8.954710721969604

# %%
model = Sequential()

#input layer
model.add(Dense(64, input_shape=(784,)))
model.add(BatchNormalization())
model.add(Activation('relu'))#Affine과 Activation사이에 BatchNormalization레이어 추가

#Hidden layer
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))

#output layer
model.add(Dense(num_classes, activation='softmax'))

model.summary()
model.compile(
            loss=keras.losses.categorical_crossentropy,
            optimizer='adam',
            metrics=['accuracy']
)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 64)                50240
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# activation_1 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________

# %%
start_time = time.time()
model.fit(
    X_train, 
    y_train,
    epochs=10,
    batch_size=100,
    verbose=1
)
print("End Time: ", time.time() - start_time)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.3344 - acc: 0.9080
# Epoch 2/10
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1248 - acc: 0.9634
# Epoch 3/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0896 - acc: 0.9733
# Epoch 4/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0707 - acc: 0.9780
# Epoch 5/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0576 - acc: 0.9823
# Epoch 6/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0469 - acc: 0.9856
# Epoch 7/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0404 - acc: 0.9872
# Epoch 8/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0360 - acc: 0.9887
# Epoch 9/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0317 - acc: 0.9895
# Epoch 10/10
# 60000/60000 [==============================] - 1s 19us/step - loss: 0.0302 - acc: 0.9902
# End Time:  12.521434545516968

# %%
def create_model(init='zeros'):
    model = Sequential()

    #input layer
    model.add(Dense(64, kernel_initializer=init, input_shape=(784,)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    #Hidden layer
    model.add(Dense(64, kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    #output layer
    model.add(Dense(num_classes, activation='softmax'))

    model.summary()
    model.compile(
                loss=keras.losses.categorical_crossentropy,
                optimizer='adam',
                metrics=['accuracy']
    )
    
    return model

# %%
param_grid = {
    'init': ['zeros', 'ones', 'glorot_uniform', 'normal', 'uniform'],
}

# %%
start_time = time.time()
model = KerasClassifier(build_fn=create_model, epochs=10, verbose=1)

grid = GridSearchCV(estimator=model, cv=2, param_grid=param_grid)
grid_result = grid.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
print("End Time: ", time.time() - start_time)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 30000/30000 [==============================] -
10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1683 - acc: 0.9490
# Epoch 3/10
# 30000/30000 [==============================] - 2s 58us/step - loss: 0.1214 - acc: 0.9621
# Epoch 4/10
# 30000/30000 [==============================] - 2s 54us/step - loss: 0.0998 - acc: 0.9685
# Epoch 5/10
# 30000/30000 [==============================] - 2s 64us/step - loss: 0.0787 - acc: 0.9754
# Epoch 6/10
# 30000/30000 [==============================] - 2s 61us/step - loss: 0.0677 - acc: 0.9788
# Epoch 7/10
# 30000/30000 [==============================] - 2s 60us/step - loss: 0.0663 - acc: 0.9786
# Epoch 8/10
# 30000/30000 [==============================] - 2s 61us/step - loss: 0.0531 - acc: 0.9830
# Epoch 9/10
# 30000/30000 [==============================] - 2s 66us/step - loss: 0.0549 - acc: 0.9812
# Epoch 10/10
# 30000/30000 [==============================] - 2s 56us/step - loss: 0.0461 - acc: 0.9845
# 30000/30000 [==============================] - 1s 30us/step
# 30000/30000 [==============================] - 1s 23us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64)                256
# _________________________________________________________________
# activation_15 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 30000/30000 [==============================] - 3s 89us/step - loss: 0.3618 - acc: 0.8960
# Epoch 2/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1670 - acc: 0.9472
# Epoch 3/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1251 - acc: 0.9612
# Epoch 4/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1015 - acc: 0.9682
# Epoch 5/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0868 - acc: 0.9725
# Epoch 6/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0761 - acc: 0.9759
# Epoch 7/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0677 - acc: 0.9774
# Epoch 8/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0605 - acc: 0.9803
# Epoch 9/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0566 - acc: 0.9810
# Epoch 10/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0497 - acc: 0.9835
# 30000/30000 [==============================] - 1s 30us/step
# 30000/30000 [==============================] - 1s 23us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# activation_17 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_18 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_33 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 30000/30000 [==============================] - 3s 88us/step - loss: 0.3599 - acc: 0.8977
# Epoch 2/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1604 - acc: 0.9513
# Epoch 3/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1197 - acc: 0.9624
# Epoch 4/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0957 - acc: 0.9702
# Epoch 5/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0802 - acc: 0.9730
# Epoch 6/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0730 - acc: 0.9756
# Epoch 7/10
# 30000/30000 [==============================] - 2s 54us/step - loss: 0.0596 - acc: 0.9808
# Epoch 8/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0552 - acc: 0.9817
# Epoch 9/10
# 30000/30000 [==============================] - 2s 56us/step - loss: 0.0522 - acc: 0.9826
# Epoch 10/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.0465 - acc: 0.9843
# 30000/30000 [==============================] - 1s 32us/step
# 30000/30000 [==============================] - 1s 24us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# activation_19 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64)                256
# _________________________________________________________________
# activation_20 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 30000/30000 [==============================] - 3s 91us/step - loss: 0.3261 - acc: 0.9060
# Epoch 2/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1609 - acc: 0.9512
# Epoch 3/10
# 30000/30000 [==============================] - 2s 55us/step - loss: 0.1208 - acc: 0.9622
# Epoch 4/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.1028 - acc: 0.9679
# Epoch 5/10
# 30000/30000 [==============================] - 2s 61us/step - loss: 0.0872 - acc: 0.9720
# Epoch 6/10
# 30000/30000 [==============================] - 2s 61us/step - loss: 0.0788 - acc: 0.9741
# Epoch 7/10
# 30000/30000 [==============================] - 2s 64us/step - loss: 0.0656 - acc: 0.9795
# Epoch 8/10
# 30000/30000 [==============================] - 2s 62us/step - loss: 0.0639 - acc: 0.9784
# Epoch 9/10
# 30000/30000 [==============================] - 2s 64us/step - loss: 0.0563 - acc: 0.9823
# Epoch 10/10
# 30000/30000 [==============================] - 2s 69us/step - loss: 0.0501 - acc: 0.9837
# 30000/30000 [==============================] - ETA:  - ETA:  - 1s 40us/step
# 30000/30000 [==============================] - 1s 29us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64)                256
# _________________________________________________________________
# activation_21 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 30000/30000 [==============================] - 3s 106us/step - loss: 0.3285 - acc: 0.9061
# Epoch 2/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.1571 - acc: 0.9522
# Epoch 3/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.1194 - acc: 0.9629
# Epoch 4/10
# 30000/30000 [==============================] - 2s 60us/step - loss: 0.0943 - acc: 0.9700
# Epoch 5/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.0810 - acc: 0.9752
# Epoch 6/10
# 30000/30000 [==============================] - 2s 60us/step - loss: 0.0747 - acc: 0.9764
# Epoch 7/10
# 30000/30000 [==============================] - 2s 60us/step - loss: 0.0627 - acc: 0.9795
# Epoch 8/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.0575 - acc: 0.9814
# Epoch 9/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.0492 - acc: 0.9840
# Epoch 10/10
# 30000/30000 [==============================] - 2s 59us/step - loss: 0.0494 - acc: 0.9833
# 30000/30000 [==============================] - 1s 37us/step
# 30000/30000 [==============================] - 1s 27us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 64)                50240
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64)                256
# _________________________________________________________________
# activation_24 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 10)                650
# =================================================================
# Total params: 55,562
# Trainable params: 55,306
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.2698 - acc: 0.9209- ETA: 3s - loss: 0.3805 - ETA: 1s - los - 5s 80us/step - loss: 0.2700 - acc: 0.9209
# Epoch 2/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1297 - acc: 0.9603
# Epoch 3/10
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1009 - acc: 0.9689
# Epoch 4/10
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0872 - acc: 0.9723
# Epoch 5/10
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0754 - acc: 0.9753
# Epoch 6/10
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0662 - acc: 0.9783
# Epoch 7/10
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0605 - acc: 0.9802
# Epoch 8/10
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.0561 - acc: 0.9812
# Epoch 9/10
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0523 - acc: 0.9826
# Epoch 10/10
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0486 - acc: 0.9843
# Best: 0.969200 using {'init': 'normal'}
# 0.112367 (0.001733) with: {'init': 'zeros'}
# 0.680850 (0.093517) with: {'init': 'ones'}
# 0.967650 (0.000850) with: {'init': 'glorot_uniform'}
# 0.969200 (0.000567) with: {'init': 'normal'}
# 0.968733 (0.000067) with: {'init': 'uniform'}
# End Time:  234.65845251083374
